# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
def detect_blur(image_path):
  img1=cv2.imread(image_path)
  img= cv2.imread(image_path,cv2.IMREAD_GRAYSCALE)
  laplacian_var=cv2.Laplacian(img,cv2.CV_64F).var()
  if laplacian_var <900:
    print("Image is Blur.Please insert a clear image")
  print(laplacian_var)
  plt.imshow(img1)
  plt.show()

# %%
detect_blur('/content/download (3).jpg')
# Out:
# Image is Blur.Please insert a clear image
# 173.81231076425453

# %%
detect_blur('/content/download (4).jpg')
# Out:
# Image is Blur.Please insert a clear image
# 809.4200599455747

# %%
detect_blur('/content/images (3).jpg')
# Out:
# Image is Blur.Please insert a clear image
# 408.32683587805496

# %%
detect_blur('/content/images (4).jpg')
# Out:
# 1214.2244140820817

# %%
detect_blur('/content/images (5).jpg')
# Out:
# 4272.016524740207

# %%
detect_blur('/content/images (6).jpg')
# Out:
# 975.9877650106779
